# %% [markdown]
# ## Zadania: LangChain Hello World i rodzaje zadań realizowanych z wykorzystaniem LLM
# Zadanie:
# 1. Uruchom poniższy kod dla 3 różnych zapytań i porównaj długość oraz strukturę odpowiedzi.
# 2. Dodaj prosty pomiar czasu wykonania (np. przy pomocy time.time()) i wypisz wyniki.
# 3. Zaimplementuj funkcję pomocniczą `run_query(text: str) -> str`, która wywoła API LLM i zwróci sam tekst odpowiedzi.

# %%
# import bibliotek
import os
from dotenv import load_dotenv
from langchain_openai import ChatOpenAI

load_dotenv()

# pobranie klucza OpenAI
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    raise ValueError("Brak klucza API w pliku .env!")

# utworzenie klienta API OpenAI z wybranym modelem
llm = ChatOpenAI(model="gpt-4o-mini", temperature=0, api_key=api_key)

# prosty prompt i request do API LLM
response = llm.invoke("Napisz krótkie pozdrowienie w języku polskim.") #<- Tu podmień prompt

print("Odpowiedź modelu:\n")
print(response.content)
# Out:
# Odpowiedź modelu:
#
# Cześć! Mam nadzieję, że masz wspaniały dzień! Pozdrawiam serdecznie!
