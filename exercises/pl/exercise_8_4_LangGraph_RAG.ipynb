# %% [markdown]
# ## Zadania: LangGraph + RAG

# %% [markdown]
# Zadanie \
# Uruchom notebook notebooks/pl/8_4_LangGraph_RAG.ipynb \
# Podmień teksty w sekscji "Przygotowanie bazy dokumentów" oraz zapytanie w sekcji "Uruchomienie grafu". \
# Zmodyfikuj graf - usuń "eval_node" (i zmodyfikuj połaczenia) w sekcji "Budowa grafu". Porównaj generowane wyniki z węzłem ewaluacyjnym oraz bez niego.
