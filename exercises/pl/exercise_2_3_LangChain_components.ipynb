# %% [markdown]
# ## Zadania: LangChain - podstawowe komponenty

# %% [markdown]
# Zadanie 1 \
# `PromptTemplate` \
# Zdefiniuj szablon i wyrenderuj komunikat. \
# Uzupełnij definicję PromptTemplate oraz wyrenderuj gotowy prompt.

# %%
from langchain_core.prompts import PromptTemplate
from dotenv import load_dotenv

load_dotenv()

# 1) Zdefiniuj zmienne wejściowe szablonu (powinny zawierać 'topic' i 'tone')
input_variables = ["topic", "tone"]

# 2) Zdefiniuj treść szablonu tak, aby używać {topic} i {tone}
template = """Napisz krótki akapit o temacie: {topic}.
Utrzymaj ton wypowiedzi: {tone}."""

prompt = PromptTemplate(input_variables=____, template=____) # <- tu uzupełnij zmienne

# 3) Wyrenderuj gotowy prompt podstawiając wartości
rendered = prompt.format(topic="uczenie maszynowe", tone="entuzjastyczny")

print(rendered)
assert "{topic}" not in rendered and "{tone}" not in rendered, "Wygląda na to, że nie sformatowałeś szablonu."
# Out:
# Napisz krótki akapit o temacie: uczenie maszynowe.
# Utrzymaj ton wypowiedzi: entuzjastyczny.

# %% [markdown]
# Zadanie 2 \
# `OutputParser` \
# Dodaj prosty parser, który wymusi zwrot zwykłego ciągu tekstowego. Uzupełnij "____", aby uzyskać poprawny łańcuch LCEL.

# %%
from langchain_core.output_parsers import ____.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.output_parsers import StrOutputParser
from langchain_core.prompts import PromptTemplate

template = "Podaj definicję pojęcia: {term} w jednym zdaniu."
prompt = PromptTemplate.from_template(template)

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)
parser = StrOutputParser()

chain = ____ | ____ | ____  # Złóż łańcuch prompt -> llm -> parser

chain.invoke({"term": "AGI"})
# Out:
# 'AGI, czyli sztuczna inteligencja ogólna, to zaawansowany typ sztucznej inteligencji, który potrafi rozumieć, uczyć się i stosować wiedzę w różnych dziedzinach na poziomie równym lub wyższym niż człowiek.'
