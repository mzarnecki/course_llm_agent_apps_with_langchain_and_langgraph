# %% [markdown]
# ## Zadania: LangGraph - wzorce agentowe

# %% [markdown]
# Zadanie \
# Agent Supervisor
# 1. Zmień pytanie przypisane do zmiennej topic i uruchom ponownie kod.
# 2. Zmień prompty dla węzłów "researcher" oraz "expert" tak aby pelnili inne role, np. "scenarzysta" i "scenograf" i uruchom ponownie kod.

# %%
import operator
from typing import Annotated, List, TypedDict
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI

from dotenv import load_dotenv
load_dotenv()

llm = ChatOpenAI(model="gpt-4o-mini", temperature=0)

class SupervisorState(TypedDict):
    """State for supervisor pattern with multiple agents."""
    topic: str
    messages: Annotated[List[str], operator.add]
    next_agent: str
    final_answer: str


def researcher_agent(state: SupervisorState) -> dict:
    """Researcher agent gathers information about the topic."""
    sys = ( # Zmodyfikuj prompt poniżej
        "You are a researcher. Your job is to gather key facts and information "
        "about the given topic. Provide 2-3 key points. Be concise."
    )
    messages_for_llm = [
        ("system", sys),
        ("user", f"Research this topic: {state['topic']}")
    ]
    resp = llm.invoke(messages_for_llm)
    research_msg = f"RESEARCHER: {resp.content}"
    return {"messages": [research_msg]}


def expert_agent(state: SupervisorState) -> dict:
    """Expert agent analyzes and provides insights based on research."""
    sys = ( # Zmodyfikuj prompt poniżej
        "You are an expert analyst. Review the research provided and give "
        "your expert analysis and conclusions. Be specific and insightful."
    )
    # Get context from previous messages
    context = "\n".join(state["messages"])
    messages_for_llm = [
        ("system", sys),
        ("user", f"Topic: {state['topic']}\n\nPrevious research:\n{context}\n\nProvide your expert analysis.")
    ]
    resp = llm.invoke(messages_for_llm)
    expert_msg = f"EXPERT: {resp.content}"
    return {"messages": [expert_msg]}


def supervisor_agent(state: SupervisorState) -> dict:
    """Supervisor decides which agent should act next or if discussion should end."""
    sys = (
        "You are a supervisor managing a research discussion between a RESEARCHER and an EXPERT. "
        "Based on the conversation so far, decide what should happen next:\n"
        "- Return 'researcher' if we need initial research or more information\n"
        "- Return 'expert' if research is done and we need expert analysis\n"
        "- Return 'end' if both research and expert analysis are complete\n\n"
        "Respond with ONLY one word: researcher, expert, or end"
    )

    context = "\n".join(state["messages"]) if state["messages"] else "No discussion yet"
    messages_for_llm = [
        ("system", sys),
        ("user", f"Topic: {state['topic']}\n\nConversation:\n{context}\n\nWhat's next?")
    ]
    resp = llm.invoke(messages_for_llm)
    next_step = resp.content.strip().lower()

    # Ensure valid response
    if next_step not in ["researcher", "expert", "end"]:
        next_step = "end"

    return {"next_agent": next_step}


def finalize_answer(state: SupervisorState) -> dict:
    """Compile final answer from the discussion."""
    sys = (
        "Summarize the research discussion into a clear, concise final answer. "
        "Include key findings and expert insights."
    )
    context = "\n".join(state["messages"])
    messages_for_llm = [
        ("system", sys),
        ("user", f"Topic: {state['topic']}\n\nDiscussion:\n{context}\n\nProvide final summary:")
    ]
    resp = llm.invoke(messages_for_llm)
    return {"final_answer": resp.content}


def route_supervisor(state: SupervisorState) -> str:
    """Route based on supervisor's decision."""
    next_agent = state.get("next_agent", "researcher")
    if next_agent == "end":
        return "finalize"
    return next_agent

supervisor_graph = StateGraph(SupervisorState)

supervisor_graph.add_node("supervisor", supervisor_agent)
supervisor_graph.add_node("researcher", researcher_agent)
supervisor_graph.add_node("expert", expert_agent)
supervisor_graph.add_node("finalize", finalize_answer)

supervisor_graph.add_edge(START, "supervisor")

supervisor_graph.add_conditional_edges(
    "supervisor",
    route_supervisor,
    {
        "researcher": "researcher",
        "expert": "expert",
        "finalize": "finalize"
    }
)

supervisor_graph.add_edge("researcher", "supervisor")
supervisor_graph.add_edge("expert", "supervisor")

supervisor_graph.add_edge("finalize", END)

supervisor_agent_graph = supervisor_graph.compile(debug=True)

topic = "What are the main benefits of using LangGraph for building AI agents?" # <- zmodyfikuj zadane pytanie

initial_state = {
    "topic": topic,
    "messages": [],
    "next_agent": "",
    "final_answer": ""
}

result = supervisor_agent_graph.invoke(initial_state)

print(f"TOPIC: {topic}\n")
print("=" * 80)
print("\nDISCUSSION:")
print("-" * 80)
for msg in result["messages"]:
    print(f"\n{msg}\n")
print("=" * 80)
print(f"\nFINAL ANSWER:\n{result['final_answer']}")
# Out:
# [values] {'topic': 'What are the main benefits of using LangGraph for building AI agents?', 'messages': [], 'next_agent': '', 'final_answer': ''}
# [updates] {'supervisor': {'next_agent': 'researcher'}}
# [values] {'topic': 'What are the main benefits of using LangGraph for building AI agents?', 'messages': [], 'next_agent': 'researcher', 'final_answer': ''}
# [updates] {'researcher': {'messages': ['RESEARCHER: 1. **Modular Design**: LangGraph offers a modular architecture that allows developers to easily integrate various components and functionalities, facilitating the rapid development and deployment of AI agents tailored to specific tasks.\n\n2. **Enhanced Natural Language Processing**: The platform leverages advanced natural language processing capabilities, enabling AI agents to understand and generate human-like text, which improves user interaction and engagement.\n\n3. **Scalability and Flexibility**: LangGraph is designed to scale efficiently, accommodating a wide range of applications from simple chatbots to complex AI systems, while also providing flexibility in adapting to different use cases and environments.']}}
# [values] {'topic': 'What are the main benefits of using LangGraph for building AI agents?', 'messages': ['RESEARCHER: 1. **Modular Design**: LangGraph offers a modular architecture that allows developers to easily integrate various components and functionalities, facilitating the rapid development and deployment of AI agents tailored to specific tasks.\n\n2. **Enhanced Natural Language Processing**: The platform leverages advanced natural language processing capabilities, enabling AI agents to understand and generate human-like text, which improves user interaction and engagement.\n\n3. **Scalability and Flexibility**: LangGraph is designed to scale efficiently, accommodating a wide range of applications from simple chatbots to complex AI systems, while also providing flexibility in adapting to different use cases and environments.'], 'next_agent': 'researcher', 'final_answer': ''}
# [updates] {'supervisor': {'next_agent': 'expert'}}
# [values] {'topic': 'What are the main benefits of using LangGraph for building AI agents?', 'messages': ['RESEARCHER: 1. **Modular Design**: LangGraph offers a modular architecture that allows developers to easily integrate various components and functionalities, facilitating the rapid development and deployment of AI agents tailored to specific tasks.\n\n2. **Enhanced Natural Language Processing**: The platform leverages advanced natural language processing capabilities, enabling AI agents to understand and generate human-like text, which improves user interaction and engagement.\n\n3. **Scalability and Flexibility**: LangGraph is designed to scale efficiently, accommodating a wide range of applications from simple chatbots to complex AI systems, while also providing flexibility in adapting to different use cases and environments.'], 'next_agent': 'expert', 'final_answer': ''}
# [updates] {'expert': {'messages': ['EXPERT: The research highlights several key benefits of using LangGraph for building AI agents, each of which plays a crucial role in the development and deployment of effective AI solutions. Here’s a detailed analysis of these benefits:\n\n1. **Modular Design**:\n   - **Analysis**: The modular architecture of LangGraph is a significant advantage for developers. It allows for the separation of concerns, meaning that different functionalities can be developed, tested, and deployed independently. This modularity not only accelerates the development process but also enhances maintainability. Developers can easily swap out or upgrade components without overhauling the entire system, which is particularly beneficial in a rapidly evolving field like AI.\n   - **Conclusion**: This design approach fosters innovation and experimentation, enabling teams to iterate quickly and respond to changing requirements or user feedback. It also lowers the barrier to entry for new developers, as they can focus on specific modules rather than needing to understand the entire system.\n\n2. **Enhanced Natural Language Processing**:\n   - **Analysis**: The emphasis on advanced natural language processing (NLP) capabilities is critical in today’s AI landscape, where user interaction is often mediated through text. LangGraph’s ability to understand and generate human-like text can significantly enhance user experience, making interactions more intuitive and engaging. This is particularly important for applications such as customer service, where the quality of communication can directly impact user satisfaction and retention.\n   - **Conclusion**: By improving the naturalness and relevance of interactions, LangGraph can help organizations build more effective AI agents that not only perform tasks but also foster a sense of connection with users. This can lead to higher engagement rates and better overall performance of AI systems.\n\n3. **Scalability and Flexibility**:\n   - **Analysis**: Scalability is a critical factor for any technology platform, especially in AI, where the demands can vary significantly based on application complexity and user load. LangGraph’s design allows it to handle everything from simple chatbots to sophisticated AI systems, making it a versatile choice for developers. The flexibility to adapt to different use cases means that organizations can leverage the same platform for various projects, reducing the need for multiple tools and streamlining development processes.\n   - **Conclusion**: This scalability and flexibility not only make LangGraph a cost-effective solution but also future-proof it against changing technological landscapes. Organizations can start small and expand their AI capabilities as needed, ensuring that they can grow and adapt without significant reinvestment in new technologies.\n\n**Overall Conclusion**:\nLangGraph presents a compelling option for developers looking to build AI agents due to its modular design, advanced NLP capabilities, and scalability. These features collectively enhance the development process, improve user engagement, and provide a robust framework for future growth. As AI continues to evolve, platforms like LangGraph that prioritize these aspects will likely become increasingly valuable in the marketplace. Organizations considering AI development should weigh these benefits carefully, as they can significantly impact the success and longevity of their AI initiatives.']}}
# [values] {'topic': 'What are the main benefits of using LangGraph for building AI agents?', 'messages': ['RESEARCHER: 1. **Modular Design**: LangGraph offers a modular architecture that allows developers to easily integrate various components and functionalities, facilitating the rapid development and deployment of AI agents tailored to specific tasks.\n\n2. **Enhanced Natural Language Processing**: The platform leverages advanced natural language processing capabilities, enabling AI agents to understand and generate human-like text, which improves user interaction and engagement.\n\n3. **Scalability and Flexibility**: LangGraph is designed to scale efficiently, accommodating a wide range of applications from simple chatbots to complex AI systems, while also providing flexibility in adapting to different use cases and environments.', 'EXPERT: The research highlights several key benefits of using LangGraph for building AI agents, each of which plays a crucial role in the development and deployment of effective AI solutions. Here’s a detailed analysis of these benefits:\n\n1. **Modular Design**:\n   - **Analysis**: The modular architecture of LangGraph is a significant advantage for developers. It allows for the separation of concerns, meaning that different functionalities can be developed, tested, and deployed independently. This modularity not only accelerates the development process but also enhances maintainability. Developers can easily swap out or upgrade components without overhauling the entire system, which is particularly beneficial in a rapidly evolving field like AI.\n   - **Conclusion**: This design approach fosters innovation and experimentation, enabling teams to iterate quickly and respond to changing requirements or user feedback. It also lowers the barrier to entry for new developers, as they can focus on specific modules rather than needing to understand the entire system.\n\n2. **Enhanced Natural Language Processing**:\n   - **Analysis**: The emphasis on advanced natural language processing (NLP) capabilities is critical in today’s AI landscape, where user interaction is often mediated through text. LangGraph’s ability to understand and generate human-like text can significantly enhance user experience, making interactions more intuitive and engaging. This is particularly important for applications such as customer service, where the quality of communication can directly impact user satisfaction and retention.\n   - **Conclusion**: By improving the naturalness and relevance of interactions, LangGraph can help organizations build more effective AI agents that not only perform tasks but also foster a sense of connection with users. This can lead to higher engagement rates and better overall performance of AI systems.\n\n3. **Scalability and Flexibility**:\n   - **Analysis**: Scalability is a critical factor for any technology platform, especially in AI, where the demands can vary significantly based on application complexity and user load. LangGraph’s design allows it to handle everything from simple chatbots to sophisticated AI systems, making it a versatile choice for developers. The flexibility to adapt to different use cases means that organizations can leverage the same platform for various projects, reducing the need for multiple tools and streamlining development processes.\n   - **Conclusion**: This scalability and flexibility not only make LangGraph a cost-effective solution but also future-proof it against changing technological landscapes. Organizations can start small and expand their AI capabilities as needed, ensuring that they can grow and adapt without significant reinvestment in new technologies.\n\n**Overall Conclusion**:\nLangGraph presents a compelling option for developers looking to build AI agents due to its modular design, advanced NLP capabilities, and scalability. These features collectively enhance the development process, improve user engagement, and provide a robust framework for f ...
# [updates] {'supervisor': {'next_agent': 'end'}}
# [values] {'topic': 'What are the main benefits of using LangGraph for building AI agents?', 'messages': ['RESEARCHER: 1. **Modular Design**: LangGraph offers a modular architecture that allows developers to easily integrate various components and functionalities, facilitating the rapid development and deployment of AI agents tailored to specific tasks.\n\n2. **Enhanced Natural Language Processing**: The platform leverages advanced natural language processing capabilities, enabling AI agents to understand and generate human-like text, which improves user interaction and engagement.\n\n3. **Scalability and Flexibility**: LangGraph is designed to scale efficiently, accommodating a wide range of applications from simple chatbots to complex AI systems, while also providing flexibility in adapting to different use cases and environments.', 'EXPERT: The research highlights several key benefits of using LangGraph for building AI agents, each of which plays a crucial role in the development and deployment of effective AI solutions. Here’s a detailed analysis of these benefits:\n\n1. **Modular Design**:\n   - **Analysis**: The modular architecture of LangGraph is a significant advantage for developers. It allows for the separation of concerns, meaning that different functionalities can be developed, tested, and deployed independently. This modularity not only accelerates the development process but also enhances maintainability. Developers can easily swap out or upgrade components without overhauling the entire system, which is particularly beneficial in a rapidly evolving field like AI.\n   - **Conclusion**: This design approach fosters innovation and experimentation, enabling teams to iterate quickly and respond to changing requirements or user feedback. It also lowers the barrier to entry for new developers, as they can focus on specific modules rather than needing to understand the entire system.\n\n2. **Enhanced Natural Language Processing**:\n   - **Analysis**: The emphasis on advanced natural language processing (NLP) capabilities is critical in today’s AI landscape, where user interaction is often mediated through text. LangGraph’s ability to understand and generate human-like text can significantly enhance user experience, making interactions more intuitive and engaging. This is particularly important for applications such as customer service, where the quality of communication can directly impact user satisfaction and retention.\n   - **Conclusion**: By improving the naturalness and relevance of interactions, LangGraph can help organizations build more effective AI agents that not only perform tasks but also foster a sense of connection with users. This can lead to higher engagement rates and better overall performance of AI systems.\n\n3. **Scalability and Flexibility**:\n   - **Analysis**: Scalability is a critical factor for any technology platform, especially in AI, where the demands can vary significantly based on application complexity and user load. LangGraph’s design allows it to handle everything from simple chatbots to sophisticated AI systems, making it a versatile choice for developers. The flexibility to adapt to different use cases means that organizations can leverage the same platform for various projects, reducing the need for multiple tools and streamlining development processes.\n   - **Conclusion**: This scalability and flexibility not only make LangGraph a cost-effective solution but also future-proof it against changing technological landscapes. Organizations can start small and expand their AI capabilities as needed, ensuring that they can grow and adapt without significant reinvestment in new technologies.\n\n**Overall Conclusion**:\nLangGraph presents a compelling option for developers looking to build AI agents due to its modular design, advanced NLP capabilities, and scalability. These features collectively enhance the development process, improve user engagement, and provide a robust framework for f ...
# [updates] {'finalize': {'final_answer': "LangGraph offers several key benefits for building AI agents, making it a valuable platform for developers. \n\n1. **Modular Design**: Its modular architecture allows for independent development and testing of components, facilitating rapid deployment and easy maintenance. This design encourages innovation and lowers the entry barrier for new developers.\n\n2. **Enhanced Natural Language Processing**: LangGraph's advanced NLP capabilities enable AI agents to understand and generate human-like text, improving user interactions and engagement, particularly in customer service applications.\n\n3. **Scalability and Flexibility**: The platform is designed to scale efficiently, accommodating a range of applications from simple chatbots to complex systems. Its flexibility allows organizations to adapt to various use cases, making it a cost-effective and future-proof solution.\n\nOverall, LangGraph enhances the development process, boosts user engagement, and provides a robust framework for growth, positioning it as a strong choice for organizations looking to invest in AI initiatives."}}
# [values] {'topic': 'What are the main benefits of using LangGraph for building AI agents?', 'messages': ['RESEARCHER: 1. **Modular Design**: LangGraph offers a modular architecture that allows developers to easily integrate various components and functionalities, facilitating the rapid development and deployment of AI agents tailored to specific tasks.\n\n2. **Enhanced Natural Language Processing**: The platform leverages advanced natural language processing capabilities, enabling AI agents to understand and generate human-like text, which improves user interaction and engagement.\n\n3. **Scalability and Flexibility**: LangGraph is designed to scale efficiently, accommodating a wide range of applications from simple chatbots to complex AI systems, while also providing flexibility in adapting to different use cases and environments.', 'EXPERT: The research highlights several key benefits of using LangGraph for building AI agents, each of which plays a crucial role in the development and deployment of effective AI solutions. Here’s a detailed analysis of these benefits:\n\n1. **Modular Design**:\n   - **Analysis**: The modular architecture of LangGraph is a significant advantage for developers. It allows for the separation of concerns, meaning that different functionalities can be developed, tested, and deployed independently. This modularity not only accelerates the development process but also enhances maintainability. Developers can easily swap out or upgrade components without overhauling the entire system, which is particularly beneficial in a rapidly evolving field like AI.\n   - **Conclusion**: This design approach fosters innovation and experimentation, enabling teams to iterate quickly and respond to changing requirements or user feedback. It also lowers the barrier to entry for new developers, as they can focus on specific modules rather than needing to understand the entire system.\n\n2. **Enhanced Natural Language Processing**:\n   - **Analysis**: The emphasis on advanced natural language processing (NLP) capabilities is critical in today’s AI landscape, where user interaction is often mediated through text. LangGraph’s ability to understand and generate human-like text can significantly enhance user experience, making interactions more intuitive and engaging. This is particularly important for applications such as customer service, where the quality of communication can directly impact user satisfaction and retention.\n   - **Conclusion**: By improving the naturalness and relevance of interactions, LangGraph can help organizations build more effective AI agents that not only perform tasks but also foster a sense of connection with users. This can lead to higher engagement rates and better overall performance of AI systems.\n\n3. **Scalability and Flexibility**:\n   - **Analysis**: Scalability is a critical factor for any technology platform, especially in AI, where the demands can vary significantly based on application complexity and user load. LangGraph’s design allows it to handle everything from simple chatbots to sophisticated AI systems, making it a versatile choice for developers. The flexibility to adapt to different use cases means that organizations can leverage the same platform for various projects, reducing the need for multiple tools and streamlining development processes.\n   - **Conclusion**: This scalability and flexibility not only make LangGraph a cost-effective solution but also future-proof it against changing technological landscapes. Organizations can start small and expand their AI capabilities as needed, ensuring that they can grow and adapt without significant reinvestment in new technologies.\n\n**Overall Conclusion**:\nLangGraph presents a compelling option for developers looking to build AI agents due to its modular design, advanced NLP capabilities, and scalability. These features collectively enhance the development process, improve user engagement, and provide a robust framework for f ...
# TOPIC: What are the main benefits of using LangGraph for building AI agents?
#
# ================================================================================
#
# DISCUSSION:
# --------------------------------------------------------------------------------
#
# RESEARCHER: 1. **Modular Design**: LangGraph offers a modular architecture that allows developers to easily integrate various components and functionalities, facilitating the rapid development and deployment of AI agents tailored to specific tasks.
#
# 2. **Enhanced Natural Language Processing**: The platform leverages advanced natural language processing capabilities, enabling AI agents to understand and generate human-like text, which improves user interaction and engagement.
#
# 3. **Scalability and Flexibility**: LangGraph is designed to scale efficiently, accommodating a wide range of applications from simple chatbots to complex AI systems, while also providing flexibility in adapting to different use cases and environments.
#
#
# EXPERT: The research highlights several key benefits of using LangGraph for building AI agents, each of which plays a crucial role in the development and deployment of effective AI solutions. Here’s a detailed analysis of these benefits:
#
# 1. **Modular Design**:
#    - **Analysis**: The modular architecture of LangGraph is a significant advantage for developers. It allows for the separation of concerns, meaning that different functionalities can be developed, tested, and deployed independently. This modularity not only accelerates the development process but also enhances maintainability. Developers can easily swap out or upgrade components without overhauling the entire system, which is particularly beneficial in a rapidly evolving field like AI.
#    - **Conclusion**: This design approach fosters innovation and experimentation, enabling teams to iterate quickly and respond to changing requirements or user feedback. It also lowers the barrier to entry for new developers, as they can focus on specific modules rather than needing to understand the entire system.
#
# 2. **Enhanced Natural Language Processing**:
#    - **Analysis**: The emphasis on advanced natural language processing (NLP) capabilities is critical in today’s AI landscape, where user interaction is often mediated through text. LangGraph’s ability to understand and generate human-like text can significantly enhance user experience, making interactions more intuitive and engaging. This is particularly important for applications such as customer service, where the quality of communication can directly impact user satisfaction and retention.
#    - **Conclusion**: By improving the naturalness and relevance of interactions, LangGraph can help organizations build more effective AI agents that not only perform tasks but also foster a sense of connection with users. This can lead to higher engagement rates and better overall performance of AI systems.
#
# 3. **Scalability and Flexibility**:
#    - **Analysis**: Scalability is a critical factor for any technology platform, especially in AI, where the demands can vary significantly based on application complexity and user load. LangGraph’s design allows it to handle everything from simple chatbots to sophisticated AI systems, making it a versatile choice for developers. The flexibility to adapt to different use cases means that organizations can leverage the same platform for various projects, reducing the need for multiple tools and streamlining development processes.
#    - **Conclusion**: This scalability and flexibility not only make LangGraph a cost-effective solution but also future-proof it against changing technological landscapes. Organizations can start small and expand their AI capabilities as needed, ensuring that they can grow and adapt without significant reinvestment in new technologies.
#
# **Overall Conclusion**:
# LangGraph presents a compelling option for developers looking to build AI agents due to its modular design, advanced NLP capabilities, and scalability. These features collectively enhance the development process, improve user engagement, and provide a robust framework for future growth. As AI continues to evolve, platforms like LangGraph that prioritize these aspects will likely become increasingly valuable in the marketplace. Organizations considering AI development should weigh these benefits carefully, as they can significantly impact the success and longevity of their AI initiatives.
#
# ================================================================================
#
# FINAL ANSWER:
# LangGraph offers several key benefits for building AI agents, making it a valuable platform for developers.
#
# 1. **Modular Design**: Its modular architecture allows for independent development and testing of components, facilitating rapid deployment and easy maintenance. This design encourages innovation and lowers the entry barrier for new developers.
#
# 2. **Enhanced Natural Language Processing**: LangGraph's advanced NLP capabilities enable AI agents to understand and generate human-like text, improving user interactions and engagement, particularly in customer service applications.
#
# 3. **Scalability and Flexibility**: The platform is designed to scale efficiently, accommodating a range of applications from simple chatbots to complex systems. Its flexibility allows organizations to adapt to various use cases, making it a cost-effective and future-proof solution.
#
# Overall, LangGraph enhances the development process, boosts user engagement, and provides a robust framework for growth, positioning it as a strong choice for organizations looking to invest in AI initiatives.
